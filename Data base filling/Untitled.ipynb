# %%
import pandas as pd
import sys
sys.path.append('../Django/polls/')
from django.db import models

# %%
path = '../data/csv/'
name = 'books.csv'
full_name = path+ name

# %%
df_books = pd.read_csv(full_name)

# %%
df_books.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
# id            1000 non-null int64
# name          1000 non-null object
# author        1000 non-null object
# genre         1000 non-null object
# seria         796 non-null object
# rating        1000 non-null float64
# count_page    1000 non-null int64
# language      1000 non-null object
# content       486 non-null object
# img_url       1000 non-null object
# dtypes: float64(1), int64(2), object(7)
# memory usage: 78.2+ KB

# %%
df_books.head()
# Out:
#    id                                          name                  author  \
# 0   0  Диетологи, я вам не верю! Книга-разоблачение          Воронин Андрей
# 1   1                     Гарри Поттер и Кубок огня    Роулинг Джоан Кэтлин
# 2   2                 Гарри Поттер и узник Азкабана    Роулинг Джоан Кэтлин
# 3   3                         В списках не значился  Васильев Борис Львович
# 4   4             Гарри Поттер и философский камень    Роулинг Джоан Кэтлин
#
#                                    genre            seria  rating  count_page  \
# 0                    Медицина и здоровье              NaN    9.95           3
# 1             Зарубежное фэнтези Фэнтези  Гарри Поттер #4    9.75          14
# 2             Зарубежное фэнтези Фэнтези  Гарри Поттер #3    9.74           8
# 3  Книги о войне Классическая литература              NaN    9.73          13
# 4             Зарубежное фэнтези Фэнтези  Гарри Поттер #1    9.73           6
#
#   language                                            content  \
# 0  Русский      Прочитай и похудей. И узнай, что реклама е...
# 1  Русский   Гарри Поттеру предстоит четвёртый год обучени...
# 2  Русский  Двенадцать долгих лет в Азкабане - мрачной тюр...
# 3  Русский  На крайнем западе нашей страны стоит Брестская...
# 4  Русский   Одиннадцатилетний мальчик-сирота Гарри Поттер...
#
#                                              img_url
# 0  https://www.litmir.me/data/Book/0/684000/68414...
# 1  https://www.litmir.me/data/Book/0/164000/16471...
# 2  https://www.litmir.me/data/Book/0/37000/37514/...
# 3  https://www.litmir.me/data/Book/0/29000/29094/...
# 4  https://www.litmir.me/data/Book/0/140000/14073...

# %%
for i,row in df_books.iterrows():
    print(row['name'])
# Out:
# Диетологи, я вам не верю! Книга-разоблачение
# 0

# %%
class PreProcessingGenre:
    def make(self, genres):
        genres_set = set('')
        genres_books = []
        # Сделать множество всех жанров и списко жанров для каждой книги
        for genres_book_str in genres:
            genres_book_list = []
            genres_book_words_list = genres_book_str.split(' ')

            if list(genres_book_words_list) == 0:
                genres_book_list.append('')
                continue

            genre_name = genres_book_words_list[0]

            for word in genres_book_words_list:
                if word[0].isupper():
                    genres_book_list.append(genre_name)
                    genres_set.add(genre_name)
                    genre_name = word
                else:
                    genre_name += ' ' + word
            genres_book_list.append(genre_name)
            genres_set.add(genre_name)
            genres_books.append(genres_book_list)

        columns = list(genres_set)
        # Сделать df для жанров тип one hot encoding
        df_genre = pd.DataFrame(columns=columns)
        for genres_book in genres_books:
            row_val = [1 if genre in genres_book else 0 for genre in columns]
            row = dict(zip(columns, row_val))
            df_genre = df_genre.append(row, ignore_index=True)
        return df_genre

# %%
prep = PreProcessingGenre()
df_genre = prep.make(df_books.genre)

for i,row in df_genre.iterrows():
    print(row[row == 1].keys())
#     print(type(row[row == 1])) 
    break
# Out:
# Index(['Медицина', 'Медицина и здоровье'], dtype='object')
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-51-e545fa0fddc4> in <module>
#       8
#       9 for i, row in df_genre.iterrows():
# ---> 10     print(list_ = list(row[row == 1]))
#      11     break
#
# TypeError: 'list_' is an invalid keyword argument for print()

# %%
for i, row in df_genre.iterrows():
    list_ = list(row[row == 1].keys())
    print(list_)
    break
# Out:
# ['Медицина', 'Медицина и здоровье']

# %%
df_lib = pd.read_csv(path + 'libraries.csv')

# %%
df_lib.head()
# Out:
#    id                                               name        type  region  \
# 0   0              Российская государственная библиотека  Библиотека  Москва
# 1   1                         Политехническая библиотека  Библиотека  Москва
# 2   2  Государственная публичная научно-техническая б...  Библиотека  Москва
# 3   3  Российская государственная библиотека для моло...  Библиотека  Москва
# 4   4     Российская государственная библиотека искусств  Библиотека  Москва
#
#   location                                  adress   latitude  longitude  \
# 0   Москва      г. Москва, ул. Воздвиженка, д. 3/5  55.751647  37.608712
# 1   Москва  г. Москва, Волгоградский пр-кт., д. 42  55.709282  37.721687
# 2   Москва   г. Москва, ул. Хорошёвская 3-я, д. 17  55.783428  37.499794
# 3   Москва    г. Москва, ул. Черкизовская Б., д. 4  55.795948  37.718355
# 4   Москва     г. Москва, ул. Дмитровка Б., д. 8/1  55.760920  37.615919
#
#                                               number  \
# 0                                 +7 (499) 557-04-70
# 1                                 +7 (495) 780-60-26
# 2                                 +7 (495) 698-93-05
# 3                   +7 (499) 922-66-77 (для справок)
# 4  +7 (495) 692-06-53 (секретарь, научно-методиче...
#
#                                    site           email  \
# 0                     http://www.rsl.ru     post@rsl.ru
# 1  https://polymus.ru/ru/museum/library  cz1@polymus.ru
# 2                   http://www.gpntb.ru  gpntb@gpntb.ru
# 3                    http://www.rgub.ru    info@rgub.ru
# 4                   http://www.liart.ru   bisk@liart.ru
#
#                                      social_networks  \
# 0  http://vk.com/leninka_ru https://www.facebook....
# 1                                                NaN
# 2  https://new.vk.com/gpntb.russia https://www.fa...
# 3  http://vk.com/rgubru https://www.facebook.com/...
# 4  http://vk.com/artlibrary https://www.facebook....
#
#                                            time_work  \
# 0  пн: 09:00 - 20:00, вт: 09:00 - 20:00, ср: 09:0...
# 1  пн: выходной, вт: 10:00 - 16:00, ср: выходной,...
# 2  пн: 10:00 - 20:00, вт: 10:00 - 20:00, ср: 10:0...
# 3  пн: 11:00 - 22:00, вт: 11:00 - 22:00, ср: 11:0...
# 4  пн: 11:00 - 19:00, вт: 11:00 - 19:00, ср: 11:0...
#
#                               img_url  \
# 0  https://b1.culture.ru/c/305358.jpg
# 1  https://b1.culture.ru/c/305352.jpg
# 2  https://b1.culture.ru/c/280639.jpg
# 3  https://b1.culture.ru/c/305236.jpg
# 4  https://b1.culture.ru/c/524319.jpg
#
#                                              content
# 0  Российская государственная библиотека – крупне...
# 1  В 2013 году после закрытия исторического здани...
# 2  Государственная публичная научно-техническая б...
# 3  Российская государственная библиотека для моло...
# 4  Российская государственная библиотека искусств...

# %%
df_event = pd.read_csv(path + 'events.csv')
df_event.head()
# Out:
#    id                        name  \
# 0   0   Выставка «Разрезая стены»
# 1   1   Выставка «Живопись минус»
# 2   2     День рождения «Фабрики»
# 3   3  Выставка «Скрытый контент»
# 4   4    Выставка «Дым и шоколад»
#
#                                            site_buy            date    town  \
# 0                                               NaN  30 апреля 2020  Москва
# 1  https://fabrika-events.timepad.ru/event/1266160/   29 марта 2020  Москва
# 2                                               NaN  31 января 2020  Москва
# 3                                               NaN  19 января 2020  Москва
# 4  https://fabrika-events.timepad.ru/event/1211968/   8 января 2020  Москва
#
#   price  age                                            img_url  \
# 0   NaN  12+  https://www.2do2go.ru/uploads/902931e92d016695...
# 1   NaN   6+  https://www.2do2go.ru/uploads/735a328ea3340c62...
# 2   NaN   0+  https://www.2do2go.ru/uploads/1a65dc11254622df...
# 3   NaN  16+  https://www.2do2go.ru/uploads/a04f6b92d240df15...
# 4   NaN   6+  https://www.2do2go.ru/uploads/6e24684c7badaa9a...
#
#                                              content  id_cultural
# 0  Персональная выставка Игоря Поносова «Разрезая...            0
# 1  Марат Гельман снова обращает внимание на бывшу...            0
# 2  Праздник начнется с открытия новых выставок: в...            0
# 3  Конец года – традиционное время подведения ито...            0
# 4  В 2018 году группа «Войти и разрешить» приняла...            0

# %%
df_center = pd.read_csv(path + 'cultural_centers.csv')
df_center.head()
# Out:
#    id                                               name  \
# 0   0               Центр творческих индустрий «Фабрика»
# 1   1                     Культурный центр «Вдохновение»
# 2   2  Архитектурно-строительный центр «Дом на Брестс...
# 3   3                          Дворец культуры «Октябрь»
# 4   4     Московский Дворец пионеров на Воробьевых горах
#
#                 offical_site         undegroud  \
# 0  http://www.fabrikacci.com  Электрозаводская
# 1                        NaN           Ясенево
# 2                        NaN        Маяковская
# 3       http://dk-october.ru               NaN
# 4  http://dvorec-pionerov.ru               NaN
#
#                                     adress                   number  \
# 0        Москва , пер. Переведеновский, 18  74992653926 74992650318
# 1                Москва , Литовский б-р, 7              74954255511
# 2            Москва , ул. Брестская 2-я, 6                      NaN
# 3  Москва , г. Подольск, ул. Свердлова, 38              74967547401
# 4                Москва , ул. Косыгина, 17              74959391450
#
#                 email                 social_netwoks   latitude   logitute  \
# 0   pr@fabrikacci.com                            NaN  55.779385  37.688926
# 1                 NaN                            NaN  55.613729  37.538843
# 2                 NaN                            NaN  55.770969  37.591459
# 3  info@dk-october.ru  https://vk.com/public78669639  55.421089  37.534879
# 4                 NaN  https://vk.com/dvorecpionerov  55.705262  37.562382
#
#                                              img_url  \
# 0  https://www.2do2go.ru/uploads/3edebc1233908323...
# 1  https://www.2do2go.ru/uploads/358057ac911e7acf...
# 2  https://www.2do2go.ru/uploads/e7b6798731711143...
# 3  https://www.2do2go.ru/uploads/bc65877ba78078aa...
# 4  https://www.2do2go.ru/uploads/0e8f4aaf985060e2...
#
#                                              content
# 0  «Фабрика» – один из столичных культурных центр...
# 1  В культурном центре&nbsp;&laquo;Вдохновение&ra...
# 2  Архитектурно-строительный центр &laquo;Дом на ...
# 3  Дворец культуры «Октябрь» образован в 1975 год...
# 4  Дворец творчества на Воробьевых горах был откр...

# %%
df_center.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284 entries, 0 to 283
# Data columns (total 12 columns):
# id                284 non-null int64
# name              283 non-null object
# offical_site      230 non-null object
# undegroud         195 non-null object
# adress            283 non-null object
# number            248 non-null object
# email             191 non-null object
# social_netwoks    179 non-null object
# latitude          284 non-null float64
# logitute          284 non-null float64
# img_url           284 non-null object
# content           248 non-null object
# dtypes: float64(2), int64(1), object(9)
# memory usage: 26.7+ KB

# %%
df_center.latitude[df_center.latitude.isna()]
# Out:
# Series([], Name: latitude, dtype: float64)

# %%
df_center[103:110]
# Out:
#       id                                     name  \
# 103  103                 Детский центр «Айликоша»
# 104  104                   Дедовский Дом культуры
# 105  105          Центр искусств им. А. В. Прядко
# 106  106      Центральный дом работников искусств
# 107  107  Зверевский центр современного искусства
# 108  108                               ДК «Экран»
# 109  109  Центр культуры и досуга «Академический»
#
#                      offical_site       undegroud  \
# 103            http://айликоша.рф    Первомайская
# 104      http://www.dedovskdk.com             NaN
# 105            http://centrisk.ru             NaN
# 106            http://www.cdri.ru  Кузнецкий мост
# 107    http://www.zverevcenter.ru      Бауманская
# 108                           NaN             NaN
# 109  http://www.academ--c.ru/node             NaN
#
#                                            adress       number  \
# 103                    Москва , ул. 7 Парковая, 5  84993910746
# 104         Москва , г. Дедовск, ул. Гагарина, 14          NaN
# 105        Москва , г. Дедовск, ул. Панфилова, 1А  74983175187
# 106            Москва , ул. Пушечная, 9\6, стр. 1  74956249347
# 107        Москва , ул. Новорязанская, 29, стр. 4  74992656166
# 108              Москва , 3-й Сетуньский пр-д, 13          NaN
# 109  Москва , ул. Большая Черемушкинская, 6, к. 2          NaN
#
#                   email                      social_netwoks   latitude  \
# 103                 NaN                                 NaN  55.794807
# 104                 NaN            https://vk.com/dedovskdk  55.860343
# 105  centrisk@yandex.ru                                 NaN  55.872629
# 106        cdri@mail.ru                                 NaN  55.761033
# 107     zverev@rinet.ru  https://www.facebook.com/Zverevsky  55.773354
# 108                 NaN            https://vk.com/ekranclub  55.731888
# 109                 NaN                                 NaN  55.688077
#
#       logitute                                            img_url  \
# 103  37.793174  https://www.2do2go.ru/uploads/b313adb73389033f...
# 104  37.120088  https://www.2do2go.ru/uploads/db79c93dd34ac2cb...
# 105  37.102783  https://www.2do2go.ru/uploads/7e748d62f26d371f...
# 106  37.624568  https://www.2do2go.ru/uploads/5617c001b1d8d12b...
# 107  37.669557  https://www.2do2go.ru/uploads/065741e866a5298b...
# 108  37.533574  https://www.2do2go.ru/uploads/91b6890bbf44d808...
# 109  37.592947  https://www.2do2go.ru/uploads/75f74d801f8195f8...
#
#                                                content
# 103  В Детском центре «Айликоша» ваш ребенок сможет...
# 104  Строительство Дома культуры со зрительным зало...
# 105  С 2011 года Центр искусств работает как культу...
# 106  ЦДРИ &ndash;&nbsp;единственный в России культу...
# 107  Зверевский центр современного искусства был ос...
# 108  Дом культуры «Экран» — современный клуб. В клу...
# 109  Место замечательных встреч и новых впечатлений...
